# %% [markdown]
# ## Robot@Home 2 - The config file `v0.1`

# %% [markdown]
# `R@H2 notebook series`
#
# <a href="https://colab.research.google.com/github/goyoambrosio/RobotAtHome2/blob/master/notebooks/50-RGBD-observations.ipynb"><img align="left" src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open in Colab" title="Open and Execute in Google Colaboratory"></a>

# %% [markdown]
# ### R@H2 functionalty introduced in this notebook:

# %% [markdown]
# -   `The config file`

# %% [markdown]
# ### Getting started

# %% [markdown]
# Install Robot@Home2 Toolbox using the Python package manager

# %%
# !pip install robotathome
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: robotathome in /usr/local/lib/python3.9/dist-packages (1.1.2)
# Requirement already satisfied: click in /usr/local/lib/python3.9/dist-packages (from robotathome) (8.1.3)
# Requirement already satisfied: numpy in /usr/local/lib/python3.9/dist-packages (from robotathome) (1.22.4)
# Requirement already satisfied: urllib3 in /usr/local/lib/python3.9/dist-packages (from robotathome) (1.26.15)
# Requirement already satisfied: loguru in /usr/local/lib/python3.9/dist-packages (from robotathome) (0.7.0)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.9/dist-packages (from robotathome) (4.65.0)
# Requirement already satisfied: requests in /usr/local/lib/python3.9/dist-packages (from robotathome) (2.27.1)
# Requirement already satisfied: humanize in /usr/local/lib/python3.9/dist-packages (from robotathome) (4.6.0)
# Requirement already satisfied: pandas in /usr/local/lib/python3.9/dist-packages (from robotathome) (1.5.3)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.9/dist-packages (from pandas->robotathome) (2022.7.1)
# Requirement already satisfied: python-dateutil>=2.8.1 in /usr/local/lib/python3.9/dist-packages (from pandas->robotathome) (2.8.2)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /usr/local/lib/python3.9/dist-packages (from requests->robotathome) (2.0.12)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.9/dist-packages (from requests->robotathome) (2022.12.7)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.9/dist-packages (from requests->robotathome) (3.4)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.9/dist-packages (from python-dateutil>=2.8.1->pandas->robotathome) (1.16.0)

# %% [markdown]
# Check that the installation has been successful

# %%
import robotathome
print (robotathome.__version__)
# Out:
# 1.1.2

# %% [markdown]
# Now, let's mount Google Drive (more info in [this notebook](https://colab.research.google.com/github/goyoambrosio/RobotAtHome2/blob/master/notebooks/05-Google-colab-drive.ipynb)).

# %%
from google.colab import drive

drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# and let's set the log level (more info in [this notebook](https://colab.research.google.com/github/goyoambrosio/RobotAtHome2/blob/master/notebooks/20-Before-starting-the-logging-system.ipynb)).

# %%
from robotathome import logger, log, set_log_level

log.set_log_level('DEBUG')  # SUCCESS is the default
level_no, level_name = log.get_current_log_level()
print(f'Current log level name: {level_name}')
# Out:
# Current log level name: DEBUG

# %% [markdown]
# ### Instantiating R@H2 with a configuration file

# %% [markdown]
# We assume that we are running this notebook in Google Colab. Therefore our
# folder structure is as follows:
#
#     /content/drive
#     └─── MyDrive
#          └─── R@H2-2.0.3
#               └── notebooks
#               └── files
#               │   ├── rgbd
#               │   └── scene
#               └── rh.db

# %% [markdown]
# As of version 1.1.0, R@H2 includes new functionality to avoid passing paths as parameters when creating an instance of the RobotAtHome class. Instead, you can use a config file like the one provided in the shared notebooks folder.
# In the next cell, we copy a default named config file `.rh` to our directory.

# %%
# !cp /content/drive/MyDrive/R@H2-2.0.3/notebooks/.rh .
# !cat .rh
# Out:
# # This is a default configuration file
# [PATHS]
# 	rh_path     = /content/drive/MyDrive/R@H2-2.0.3
# 	rgbd_path   = os.path.join(my_rh_path, 'files/rgbd')
# 	scene_path  = os.path.join(my_rh_path, 'files/scene')
# 	wspc_path   = /content/drive/MyDrive/Colab Notebooks
# 	db_filename = rh.db

# %% [markdown]
# With the configuration file in our directory, we simply create an instance of the class without any parameters

# %%
from robotathome import RobotAtHome

try: 
      rh = RobotAtHome()
except:
      logger.error("Something was wrong")
# Out:
# 2023-04-16 16:00:43.155 | DEBUG    | robotathome.core.reader:__init__:115 - rh_path     : /content/drive/MyDrive/R@H2-2.0.3
# 2023-04-16 16:00:43.160 | DEBUG    | robotathome.core.reader:__init__:116 - rgbd_path   : os.path.join(my_rh_path, 'files/rgbd')
# 2023-04-16 16:00:43.164 | DEBUG    | robotathome.core.reader:__init__:117 - scene_path  : os.path.join(my_rh_path, 'files/scene')
# 2023-04-16 16:00:43.166 | DEBUG    | robotathome.core.reader:__init__:118 - wspc_path   : /content/drive/MyDrive/Colab Notebooks
# 2023-04-16 16:00:43.169 | DEBUG    | robotathome.core.reader:__init__:119 - db_filename : rh.db
# 2023-04-16 16:00:43.173 | DEBUG    | robotathome.core.reader:__open_dataset:135 - db_full_path: /content/drive/MyDrive/R@H2-2.0.3/rh.db
# 2023-04-16 16:00:43.176 | DEBUG    | robotathome.core.reader:__open_dataset:139 - db_full_filename: file:/content/drive/MyDrive/R@H2-2.0.3/rh.db?mode=rw
# 2023-04-16 16:00:43.180 | SUCCESS  | robotathome.core.reader:__open_dataset:141 - Connection is established: rh.db

# %% [markdown]
# You can write as many configuration files as you need. So, if you want to apply some of them, say 'my_cfg_file', you'll need to instantiate the class in this way:
# ```
# my_rh = RobotAtHome(config_filename='my_cfg_file')
# ```
# Of course, you can always to use the previous programatic method.

# %%
help(RobotAtHome.__init__)
# Out:
# Help on function __init__ in module robotathome.core.reader:
#
# __init__(self, rh_path='.', rgbd_path='./files/rgbd', scene_path='./files/scene', wspc_path='.', db_filename='rh.db', config_filename='.rh')
#     Initialize instance variables.
#
#     There are two ways to get initial values for main attributes:
#     with arguments values or by reading a configuration file. This function
#     first tries to read a file called .rh . If the file does not exist,
#     the attributes get values from the arguments. Additionally, arguments
#     can be provided or default values can be obtained.
#
#     Attributes:
#         rh_path: path where the database resides.
#         rgbd_path: path where rgbd files are located.
#         scene_path: path where scene files are located.
#         wspc_path: workspace path where the toolbox stores results or
#             intermediate data.
#         db_filename: file name of the database.
#
#     Raises:
#         Exception: If the object cannot be instantiated (usually because
#             a database connection could not be done).
#
#     Note 1: The default folder structure is:
#         R@H2-2.0.1
#              │    └── files
#              │        ├── rgbd
#              │        └── scene
#              └─────── rh.db
#
#     Note 2: Example of .rh file
#         # This is a default configuration file
#         [PATHS]
#         rh_path     = $HOME/R@H2-2.0.1
#         rgbd_path   = ~/R@H2-2.0.1/files/rgbd
#         scene_path  = ~/R@H2-2.0.1/files/scene
#         wspc_path   = ~/R@H2-2.0.1
#         db_filename = rh.db
#
#         Paths strings can content environmental variables such as $HOME or
#         a tilde prefix.

# %% [markdown]
# <a href="https://colab.research.google.com/github/goyoambrosio/RobotAtHome2/blob/master/notebooks/50-RGBD-observations.ipynb"><img align="left" src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open in Colab" title="Open and Execute in Google Colaboratory"></a>
